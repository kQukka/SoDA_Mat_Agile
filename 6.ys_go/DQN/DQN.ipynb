# %%
import os
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import RandomUniform


# 상태가 입력, 큐함수가 출력인 인공신경망 생성
class DQN(tf.keras.Model):
    def __init__(self, action_size):
        super(DQN, self).__init__()
        self.fc1 = Dense(24, activation='relu')
        self.fc2 = Dense(24, activation='relu')
        self.fc_out = Dense(action_size,
                            kernel_initializer=RandomUniform(-1e-3, 1e-3))

    def call(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        q = self.fc_out(x)
        return q


# 카트폴 예제에서의 DQN 에이전트
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.render = False

        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 1000

        # 리플레이 메모리, 최대 크기 2000
        self.memory = deque(maxlen=2000)

        # 모델과 타깃 모델 생성
        self.model = DQN(action_size)
        self.target_model = DQN(action_size)
        self.optimizer = Adam(lr=self.learning_rate)

        # 타깃 모델 초기화
        self.update_target_model()

    # 타깃 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model(state)
            return np.argmax(q_value[0])

    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        mini_batch = random.sample(self.memory, self.batch_size)

        states = np.array([sample[0][0] for sample in mini_batch])
        actions = np.array([sample[1] for sample in mini_batch])
        rewards = np.array([sample[2] for sample in mini_batch])
        next_states = np.array([sample[3][0] for sample in mini_batch])
        dones = np.array([sample[4] for sample in mini_batch])

        # 학습 파라메터
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            # 현재 상태에 대한 모델의 큐함수
            predicts = self.model(states)
            one_hot_action = tf.one_hot(actions, self.action_size)
            predicts = tf.reduce_sum(one_hot_action * predicts, axis=1)

            # 다음 상태에 대한 타깃 모델의 큐함수
            target_predicts = self.target_model(next_states)
            target_predicts = tf.stop_gradient(target_predicts)

            # 벨만 최적 방정식을 이용한 업데이트 타깃
            max_q = np.amax(target_predicts, axis=-1)
            targets = rewards + (1 - dones) * self.discount_factor * max_q
            loss = tf.reduce_mean(tf.square(targets - predicts))

        # 오류함수를 줄이는 방향으로 모델 업데이트
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))


if __name__ == "__main__":
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # DQN 에이전트 생성
    agent = DQNAgent(state_size, action_size)

    scores, episodes = [], []
    score_avg = 0

    num_episode = 300
    for e in range(num_episode):
        done = False
        score = 0
        # env 초기화
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            # 현재 상태로 행동을 선택
            action = agent.get_action(state)
            # 선택한 행동으로 환경에서 한 타임스텝 진행
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])

            # 타임스텝마다 보상 0.1, 에피소드가 중간에 끝나면 -1 보상
            score += reward
            reward = 0.1 if not done or score == 500 else -1

            # 리플레이 메모리에 샘플 <s, a, r, s'> 저장
            agent.append_sample(state, action, reward, next_state, done)
            # 매 타임스텝마다 학습
            if len(agent.memory) >= agent.train_start:
                agent.train_model()

            state = next_state

            if done:
                # 각 에피소드마다 타깃 모델을 모델의 가중치로 업데이트
                agent.update_target_model()
                # 에피소드마다 학습 결과 출력
                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print("episode: {:3d} | score avg: {:3.2f} | memory length: {:4d} | epsilon: {:.4f}".format(
                      e, score_avg, len(agent.memory), agent.epsilon))

                # 에피소드마다 학습 결과 그래프로 저장
                scores.append(score_avg)
                episodes.append(e)
                pylab.plot(episodes, scores, 'b')
                pylab.xlabel("episode")
                pylab.ylabel("average score")
                pylab.savefig("graph.png")

                # 이동 평균이 400 이상일 때 종료
                if score_avg > 400:
                    agent.model.save_weights("/content", save_format="tf")
                    sys.exit()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# episode:   0 | score avg: 10.00 | memory length:   10 | epsilon: 1.0000
# episode:   1 | score avg: 10.40 | memory length:   24 | epsilon: 1.0000
# episode:   2 | score avg: 11.36 | memory length:   44 | epsilon: 1.0000
# episode:   3 | score avg: 11.72 | memory length:   59 | epsilon: 1.0000
# episode:   4 | score avg: 17.05 | memory length:  124 | epsilon: 1.0000
# episode:   5 | score avg: 16.85 | memory length:  139 | epsilon: 1.0000
# episode:   6 | score avg: 20.06 | memory length:  188 | epsilon: 1.0000
# episode:   7 | score avg: 19.86 | memory length:  206 | epsilon: 1.0000
# episode:   8 | score avg: 19.07 | memory length:  218 | epsilon: 1.0000
# episode:   9 | score avg: 18.86 | memory length:  235 | epsilon: 1.0000
# episode:  10 | score avg: 18.18 | memory length:  247 | epsilon: 1.0000
# episode:  11 | score avg: 17.46 | memory length:  258 | epsilon: 1.0000
# episode:  12 | score avg: 17.61 | memory length:  277 | epsilon: 1.0000
# episode:  13 | score avg: 17.45 | memory length:  293 | epsilon: 1.0000
# episode:  14 | score avg: 16.81 | memory length:  304 | epsilon: 1.0000
# episode:  15 | score avg: 17.23 | memory length:  325 | epsilon: 1.0000
# episode:  16 | score avg: 17.00 | memory length:  340 | epsilon: 1.0000
# episode:  17 | score avg: 16.80 | memory length:  355 | epsilon: 1.0000
# episode:  18 | score avg: 18.32 | memory length:  387 | epsilon: 1.0000
# episode:  19 | score avg: 18.09 | memory length:  403 | epsilon: 1.0000
# episode:  20 | score avg: 20.98 | memory length:  450 | epsilon: 1.0000
# episode:  21 | score avg: 20.28 | memory length:  464 | epsilon: 1.0000
# episode:  22 | score avg: 20.55 | memory length:  487 | epsilon: 1.0000
# episode:  23 | score avg: 20.10 | memory length:  503 | epsilon: 1.0000
# episode:  24 | score avg: 20.09 | memory length:  523 | epsilon: 1.0000
# episode:  25 | score avg: 21.38 | memory length:  556 | epsilon: 1.0000
# episode:  26 | score avg: 22.24 | memory length:  586 | epsilon: 1.0000
# episode:  27 | score avg: 22.02 | memory length:  606 | epsilon: 1.0000
# episode:  28 | score avg: 22.42 | memory length:  632 | epsilon: 1.0000
# episode:  29 | score avg: 21.57 | memory length:  646 | epsilon: 1.0000
# episode:  30 | score avg: 21.52 | memory length:  667 | epsilon: 1.0000
# episode:  31 | score avg: 20.97 | memory length:  683 | epsilon: 1.0000
# episode:  32 | score avg: 20.37 | memory length:  698 | epsilon: 1.0000
# episode:  33 | score avg: 20.13 | memory length:  716 | epsilon: 1.0000
# episode:  34 | score avg: 20.22 | memory length:  737 | epsilon: 1.0000
# episode:  35 | score avg: 20.90 | memory length:  764 | epsilon: 1.0000
# episode:  36 | score avg: 20.41 | memory length:  780 | epsilon: 1.0000
# episode:  37 | score avg: 21.17 | memory length:  808 | epsilon: 1.0000
# episode:  38 | score avg: 20.55 | memory length:  823 | epsilon: 1.0000
# episode:  39 | score avg: 20.69 | memory length:  845 | epsilon: 1.0000
# episode:  40 | score avg: 20.83 | memory length:  867 | epsilon: 1.0000
# episode:  41 | score avg: 23.04 | memory length:  910 | epsilon: 1.0000
# episode:  42 | score avg: 21.64 | memory length:  919 | epsilon: 1.0000
# episode:  43 | score avg: 20.87 | memory length:  933 | epsilon: 1.0000
# episode:  44 | score avg: 19.89 | memory length:  944 | epsilon: 1.0000
# episode:  45 | score avg: 19.90 | memory length:  964 | epsilon: 1.0000
# episode:  46 | score avg: 21.41 | memory length:  999 | epsilon: 1.0000
# episode:  47 | score avg: 24.07 | memory length: 1047 | epsilon: 0.9531
# episode:  48 | score avg: 24.16 | memory length: 1072 | epsilon: 0.9296
# episode:  49 | score avg: 23.04 | memory length: 1085 | epsilon: 0.9176
# episode:  50 | score avg: 27.04 | memory length: 1148 | epsilon: 0.8615
# episode:  51 | score avg: 28.34 | memory length: 1188 | epsilon: 0.8277
# episode:  52 | score avg: 34.10 | memory length: 1274 | epsilon: 0.7595
# episode:  53 | score avg: 36.59 | memory length: 1333 | epsilon: 0.7159
# episode:  54 | score avg: 36.03 | memory length: 1364 | epsilon: 0.6941
# episode:  55 | score avg: 38.93 | memory length: 1429 | epsilon: 0.6504
# episode:  56 | score avg: 44.84 | memory length: 1527 | epsilon: 0.5896
# episode:  57 | score avg: 42.15 | memory length: 1545 | epsilon: 0.5791
# episode:  58 | score avg: 41.64 | memory length: 1582 | epsilon: 0.5581
# episode:  59 | score avg: 52.97 | memory length: 1737 | epsilon: 0.4779
# episode:  60 | score avg: 55.68 | memory length: 1817 | epsilon: 0.4411
# episode:  61 | score avg: 66.11 | memory length: 1977 | epsilon: 0.3759
# episode:  62 | score avg: 77.80 | memory length: 2000 | epsilon: 0.3130
# episode:  63 | score avg: 89.72 | memory length: 2000 | epsilon: 0.2570
# episode:  64 | score avg: 95.75 | memory length: 2000 | epsilon: 0.2212
# episode:  65 | score avg: 102.97 | memory length: 2000 | epsilon: 0.1870
# episode:  66 | score avg: 116.77 | memory length: 2000 | epsilon: 0.1469
# episode:  67 | score avg: 124.80 | memory length: 2000 | epsilon: 0.1206
# episode:  68 | score avg: 134.32 | memory length: 2000 | epsilon: 0.0968
# episode:  69 | score avg: 146.39 | memory length: 2000 | epsilon: 0.0750
# episode:  70 | score avg: 152.25 | memory length: 2000 | epsilon: 0.0611
# episode:  71 | score avg: 159.42 | memory length: 2000 | epsilon: 0.0488
# episode:  72 | score avg: 173.38 | memory length: 2000 | epsilon: 0.0362
# episode:  73 | score avg: 183.84 | memory length: 2000 | epsilon: 0.0274
# episode:  74 | score avg: 181.96 | memory length: 2000 | epsilon: 0.0232
# episode:  75 | score avg: 181.36 | memory length: 2000 | epsilon: 0.0195
# episode:  76 | score avg: 181.13 | memory length: 2000 | epsilon: 0.0163
# episode:  77 | score avg: 180.41 | memory length: 2000 | epsilon: 0.0137
# episode:  78 | score avg: 181.27 | memory length: 2000 | epsilon: 0.0113
# episode:  79 | score avg: 197.14 | memory length: 2000 | epsilon: 0.0100
# episode:  80 | score avg: 194.73 | memory length: 2000 | epsilon: 0.0100
# episode:  81 | score avg: 194.06 | memory length: 2000 | epsilon: 0.0100
# episode:  82 | score avg: 189.95 | memory length: 2000 | epsilon: 0.0100
# episode:  83 | score avg: 185.46 | memory length: 2000 | epsilon: 0.0100
# episode:  84 | score avg: 181.41 | memory length: 2000 | epsilon: 0.0100
# episode:  85 | score avg: 185.87 | memory length: 2000 | epsilon: 0.0100
# episode:  86 | score avg: 182.38 | memory length: 2000 | epsilon: 0.0100
# episode:  87 | score avg: 179.14 | memory length: 2000 | epsilon: 0.0100
# episode:  88 | score avg: 177.03 | memory length: 2000 | epsilon: 0.0100
# episode:  89 | score avg: 174.43 | memory length: 2000 | epsilon: 0.0100
# episode:  90 | score avg: 173.88 | memory length: 2000 | epsilon: 0.0100
# episode:  91 | score avg: 181.40 | memory length: 2000 | epsilon: 0.0100
# episode:  92 | score avg: 178.86 | memory length: 2000 | epsilon: 0.0100
# episode:  93 | score avg: 179.57 | memory length: 2000 | epsilon: 0.0100
# episode:  94 | score avg: 177.41 | memory length: 2000 | epsilon: 0.0100
# episode:  95 | score avg: 175.97 | memory length: 2000 | epsilon: 0.0100
# episode:  96 | score avg: 174.18 | memory length: 2000 | epsilon: 0.0100
# episode:  97 | score avg: 172.26 | memory length: 2000 | epsilon: 0.0100
# episode:  98 | score avg: 174.13 | memory length: 2000 | epsilon: 0.0100
# episode:  99 | score avg: 171.92 | memory length: 2000 | epsilon: 0.0100
# episode: 100 | score avg: 168.63 | memory length: 2000 | epsilon: 0.0100
# episode: 101 | score avg: 172.06 | memory length: 2000 | epsilon: 0.0100
# episode: 102 | score avg: 170.56 | memory length: 2000 | epsilon: 0.0100
# episode: 103 | score avg: 169.60 | memory length: 2000 | epsilon: 0.0100
# episode: 104 | score avg: 167.84 | memory length: 2000 | epsilon: 0.0100
# episode: 105 | score avg: 170.06 | memory length: 2000 | epsilon: 0.0100
# episode: 106 | score avg: 170.25 | memory length: 2000 | epsilon: 0.0100
# episode: 107 | score avg: 167.73 | memory length: 2000 | epsilon: 0.0100
# episode: 108 | score avg: 170.25 | memory length: 2000 | epsilon: 0.0100
# episode: 109 | score avg: 166.53 | memory length: 2000 | epsilon: 0.0100
# episode: 110 | score avg: 167.18 | memory length: 2000 | epsilon: 0.0100
# episode: 111 | score avg: 168.86 | memory length: 2000 | epsilon: 0.0100
# episode: 112 | score avg: 166.17 | memory length: 2000 | epsilon: 0.0100
# episode: 113 | score avg: 163.96 | memory length: 2000 | epsilon: 0.0100
# episode: 114 | score avg: 157.16 | memory length: 2000 | epsilon: 0.0100
# episode: 115 | score avg: 156.14 | memory length: 2000 | epsilon: 0.0100
# episode: 116 | score avg: 152.33 | memory length: 2000 | epsilon: 0.0100
# episode: 117 | score avg: 150.10 | memory length: 2000 | epsilon: 0.0100
# episode: 118 | score avg: 149.19 | memory length: 2000 | epsilon: 0.0100
# episode: 119 | score avg: 154.47 | memory length: 2000 | epsilon: 0.0100
# episode: 120 | score avg: 157.22 | memory length: 2000 | epsilon: 0.0100
# episode: 121 | score avg: 154.60 | memory length: 2000 | epsilon: 0.0100
# episode: 122 | score avg: 161.64 | memory length: 2000 | epsilon: 0.0100
# episode: 123 | score avg: 160.08 | memory length: 2000 | epsilon: 0.0100
# episode: 124 | score avg: 159.27 | memory length: 2000 | epsilon: 0.0100
# episode: 125 | score avg: 158.04 | memory length: 2000 | epsilon: 0.0100
# episode: 126 | score avg: 158.24 | memory length: 2000 | epsilon: 0.0100
# episode: 127 | score avg: 169.21 | memory length: 2000 | epsilon: 0.0100
# episode: 128 | score avg: 166.99 | memory length: 2000 | epsilon: 0.0100
# episode: 129 | score avg: 167.99 | memory length: 2000 | epsilon: 0.0100
# episode: 130 | score avg: 175.69 | memory length: 2000 | epsilon: 0.0100
# episode: 131 | score avg: 179.52 | memory length: 2000 | epsilon: 0.0100
# episode: 132 | score avg: 179.77 | memory length: 2000 | epsilon: 0.0100
# episode: 133 | score avg: 177.89 | memory length: 2000 | epsilon: 0.0100
# episode: 134 | score avg: 176.91 | memory length: 2000 | epsilon: 0.0100
# episode: 135 | score avg: 174.41 | memory length: 2000 | epsilon: 0.0100
# episode: 136 | score avg: 173.67 | memory length: 2000 | epsilon: 0.0100
# episode: 137 | score avg: 169.61 | memory length: 2000 | epsilon: 0.0100
# episode: 138 | score avg: 153.75 | memory length: 2000 | epsilon: 0.0100
# episode: 139 | score avg: 152.87 | memory length: 2000 | epsilon: 0.0100
# episode: 140 | score avg: 150.98 | memory length: 2000 | epsilon: 0.0100
# episode: 141 | score avg: 147.89 | memory length: 2000 | epsilon: 0.0100
# episode: 142 | score avg: 145.00 | memory length: 2000 | epsilon: 0.0100
# episode: 143 | score avg: 143.30 | memory length: 2000 | epsilon: 0.0100
# episode: 144 | score avg: 140.57 | memory length: 2000 | epsilon: 0.0100
# episode: 145 | score avg: 141.91 | memory length: 2000 | epsilon: 0.0100
# episode: 146 | score avg: 148.92 | memory length: 2000 | epsilon: 0.0100
# episode: 147 | score avg: 156.73 | memory length: 2000 | epsilon: 0.0100
# episode: 148 | score avg: 174.05 | memory length: 2000 | epsilon: 0.0100
# episode: 149 | score avg: 176.65 | memory length: 2000 | epsilon: 0.0100
# episode: 150 | score avg: 182.38 | memory length: 2000 | epsilon: 0.0100
# episode: 151 | score avg: 184.05 | memory length: 2000 | epsilon: 0.0100
# episode: 152 | score avg: 185.54 | memory length: 2000 | epsilon: 0.0100
# episode: 153 | score avg: 181.19 | memory length: 2000 | epsilon: 0.0100
# episode: 154 | score avg: 185.47 | memory length: 2000 | epsilon: 0.0100
# episode: 155 | score avg: 190.52 | memory length: 2000 | epsilon: 0.0100
# episode: 156 | score avg: 190.57 | memory length: 2000 | epsilon: 0.0100
# episode: 157 | score avg: 185.61 | memory length: 2000 | epsilon: 0.0100
# episode: 158 | score avg: 185.55 | memory length: 2000 | epsilon: 0.0100
# episode: 159 | score avg: 187.10 | memory length: 2000 | epsilon: 0.0100
# episode: 160 | score avg: 184.49 | memory length: 2000 | epsilon: 0.0100
# episode: 161 | score avg: 186.04 | memory length: 2000 | epsilon: 0.0100
# episode: 162 | score avg: 185.63 | memory length: 2000 | epsilon: 0.0100
# episode: 163 | score avg: 186.57 | memory length: 2000 | epsilon: 0.0100
# episode: 164 | score avg: 182.01 | memory length: 2000 | epsilon: 0.0100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-535111bc09b2> in <module>()
#     134
#     135             # 현재 상태로 행동을 선택
# --> 136             action = agent.get_action(state)
#     137             # 선택한 행동으로 환경에서 한 타임스텝 진행
#     138             next_state, reward, done, info = env.step(action)
#
# <ipython-input-2-535111bc09b2> in get_action(self, state)
#      66             return random.randrange(self.action_size)
#      67         else:
# ---> 68             q_value = self.model(state)
#      69             return np.argmax(q_value[0])
#      70
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1094         with autocast_variable.enable_auto_cast_variables(
#    1095             self._compute_dtype_object):
# -> 1096           outputs = call_fn(inputs, *args, **kwargs)
#    1097
#    1098         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# <ipython-input-2-535111bc09b2> in call(self, x)
#      23     def call(self, x):
#      24         x = self.fc1(x)
# ---> 25         x = self.fc2(x)
#      26         q = self.fc_out(x)
#      27         return q
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1029     # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#    1030     # >> model = tf.keras.Model(inputs, outputs)
# -> 1031     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#    1032       return self._functional_construction_call(inputs, args, kwargs,
#    1033                                                 input_list)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in _in_functional_construction_mode(layer, inputs, args, kwargs, input_list)
#    3375   return any(
#    3376       isinstance(tensor, keras_tensor.KerasTensor)
# -> 3377       for tensor in tf.nest.flatten([inputs, args, kwargs]))
#    3378
#    3379
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in flatten(structure, expand_composites)
#     449     return [None]
#     450   expand_composites = bool(expand_composites)
# --> 451   return _pywrap_utils.Flatten(structure, expand_composites)
#     452
#     453
#
# KeyboardInterrupt:
